# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # The Data

# %% [markdown]
# There are some fake data csv file u can read in the statement

# %%
df1=pd.read_csv('df1', index_col=0)
df2=pd.read_csv('df2')

# %%
df1.head(7)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# 2000-01-06 -0.891165  0.741147  0.237482 -1.501909
# 2000-01-07  1.111132  0.287674  0.183012  1.359046

# %%
plt.style.use('fivethirtyeight')

# %%
df1['A'].hist(bins=30,edgecolor='k')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
# plt.style.use('ggplot')
# plt.style.use('fivethirtyeight')
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
df1['A'].hist(bins=30, edgecolor='k')
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist(bins=30, edgecolor='k')
# Out:
# <AxesSubplot:>

# %% [raw]
# df.plot.area
# df.plot.barh
# df.plot.density
# df.plot.hit
# df.plot.line

# %% [markdown]
# # AREA

# %%
plt.style.use('Solarize_Light2')

# %%
df2.plot.area(alpha=0.82)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plots

# %%
df1.plot.scatter(x='A',y='B')
plt.style.use('seaborn-darkgrid')

# %%
df1.plot.scatter(x='A',y='B', c='C', cmap='rainbow')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B', c='C', cmap='prism_r')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B', c='C', s=df1['C']*60, cmap='rainbow')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# # Boxplots

# %%
df2.plot.box()
plt.style.use('ggplot')

# %% [markdown]
# # Hexagonal Bin Plot

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df.plot.hexbin(x='a',y='b', gridsize=20, cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
