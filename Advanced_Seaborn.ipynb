# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris_df=sns.load_dataset('iris')

# %%
iris_df.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
#scatterpot x='sepal_width', y='sepal_length'
sns.scatterplot(x='sepal_width',y='sepal_length', data=iris_df, hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
palette_dict={x:'gray' for x in iris_df['species'].unique()}

# %%
palette_dict
# Out:
# {'setosa': 'gray', 'versicolor': 'gray', 'virginica': 'gray'}

# %%
palette_dict['virginica']='red'

# %%
palette_dict
# Out:
# {'setosa': 'gray', 'versicolor': 'gray', 'virginica': 'red'}

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='sepal_width',y='sepal_length', data=iris_df, hue='species', palette=palette_dict, size='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# # Accessing Palette

# %%
sns.scatterplot(x='sepal_width',y='sepal_length', data=iris_df, hue='species', palette='ocean_r', size='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
#len(palette_list)

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
Blue, Orange, Green, Red, Purple = sns.color_palette()[0:5]

# %%
b=sns.color_palette()[9:10]

# %%
sns.light_palette('blue')
# Out:
# [(0.9427942677547513, 0.942825384792593, 0.9519953287278279),
#  (0.754235414203801, 0.7542603078340744, 0.9615962629822623),
#  (0.5656765606528508, 0.5656952308755558, 0.9711971972366967),
#  (0.3771177071019005, 0.3771301539170372, 0.9807981314911312),
#  (0.18855885355095026, 0.18856507695851854, 0.9903990657455656),
#  (0.0, 0.0, 1.0)]

# %%
sns.light_palette('orange')
# Out:
# [(0.952371654702472, 0.9416756878349389, 0.935002444561772),
#  (0.9618973237619776, 0.8827523149738336, 0.7480019556494175),
#  (0.9714229928214831, 0.8238289421127281, 0.5610014667370631),
#  (0.9809486618809888, 0.7649055692516227, 0.37400097782470876),
#  (0.9904743309404944, 0.7059821963905172, 0.18700048891235432),
#  (1.0, 0.6470588235294118, 0.0)]

# %%
G=sns.light_palette('Green')

# %%
O=sns.light_palette('orange')[2]

# %%
BLUE=sns.light_palette('blue')[5]

# %%
sns.jointplot(x='sepal_width',y='sepal_length', data=iris_df, color=O, marginal_kws={'color':BLUE})

# %%
# sns.light_palette('red')

# %%
# sns.dark_palette('red')

# %%
sns.set_style('darkgrid')

# %%
# %matplotlib inline

# %%
# g=sns.PairGrid(iris_df)
# g = g.map_offdiag(sns.histplot)
# plt.show()
g = sns.pairplot(iris_df)
g = g.map_diag(sns.kdeplot)
plt.show()

# %%
# g=sns.PairGrid(iris_df)
# g = g.map_offdiag(sns.histplot)
sns.PairGrid(iris_df)
g = sns.pairplot(iris_df)
g = g.map_diag(sns.kdeplot)
plt.show()

# %%
sns.pairplot(iris_df)

# %%
g=sns.PairGrid(iris_df)
g = g.map_offdiag(sns.histplot)
plt.show()
# g.map_diag(plt.kdeplot);

# %%
g=sns.PairGrid(iris_df)
g.map_offdiag(sns.histplot())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 g=sns.PairGrid(iris_df)
# ----> 2 g.map_offdiag(sns.histplot())
#       3 plt.show()
#
# File E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\axisgrid.py:1387, in PairGrid.map_offdiag(self, func, **kwargs)
#    1376 """Plot with a bivariate function on the off-diagonal subplots.
#    1377
#    1378 Parameters
#    (...)
#    1384
#    1385 """
#    1386 if self.square_grid:
# -> 1387     self.map_lower(func, **kwargs)
#    1388     if not self._corner:
#    1389         self.map_upper(func, **kwargs)
#
# File E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\axisgrid.py:1357, in PairGrid.map_lower(self, func, **kwargs)
#    1346 """Plot with a bivariate function on the lower diagonal subplots.
#    1347
#    1348 Parameters
#    (...)
#    1354
# ...

# %%
g = g.map(plt.scatter)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns

iris = sns.load_dataset('iris')

g = sns.PairGrid(iris)
color_for_trainingset = 'paleturquoise'
# color_for_trainingset = sns.color_palette('husl', 2) [-1] # this is the color from the question
g.map_upper(sns.scatterplot, alpha=0.2, color=color_for_trainingset)
g.map_lower(sns.kdeplot, color=color_for_trainingset)
g.map_diag(sns.kdeplot, lw=3, color=color_for_trainingset)

g.data = iris.iloc[:1]
# g.data = data[data['type'] == 'Target 1']
g.map_upper(sns.scatterplot, alpha=1, color='red')
g.map_lower(sns.scatterplot, alpha=1, color='red', zorder=3)

handles = [Line2D([], [], color='red', ls='', marker='o', label='target'),
           Line2D([], [], color=color_for_trainingset, lw=3, label='training set')]
g.add_legend(handles=handles)

plt.show()
# Out:
# E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\axisgrid.py:156: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   figlegend = self._figure.legend(handles, labels, **kwargs)

# %%
green=sns.light_palette('green')[4]

# %%
blue=sns.light_palette('blue')[5]

# %%
orange=sns.light_palette('orange')[-1]

# %%
g=sns.PairGrid(iris_df)
g.map_lower(sns.scatterplot, color='green')
g.map_diag(sns.boxplot, color='blue')
g.map_upper(sns.kdeplot, color='orange')

# %%
g=sns.PairGrid(iris_df, corner=True)
g.map_offdiag(sns.scatterplot)
g.map_diag(sns.boxplot)

# %%
g=sns.PairGrid(iris_df,hue='species',diag_sharey=False, vars=['petal_length','petal_width'], size=5)
#g.map_lower(sns.scatterplot)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
# Out:
# E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\axisgrid.py:1209: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))

# %%
g=sns.PairGrid(iris_df,diag_sharey=False, x_vars=['sepal_length','sepal_width','petal_width']
               ,y_vars=['petal_length'])
g.map(sns.scatterplot)
# g.map_diag(sns.kdeplot)
#g.map_offdiag(sns.kdeplot)

# %%
g=sns.PairGrid(iris_df, hue='species', diag_sharey=False)
g.map_diag(sns.kdeplot,fill=True,lw=3,ls='--')
g.map_offdiag(sns.scatterplot)

# %%
# !pip install ipywidgets

# %%
import ipywidgets as widgets

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)
