# %% [markdown]
# # Distribution Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Data

# %%
tips=sns.load_dataset('tips')

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %% [markdown]
# # Distplot

# %% [markdown]
# The dist shows the distribution of a univariate set of observations

# %%
sns.distplot(tips['total_bill'])
# Out:
# E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'])
sns.despine(left=True)
# Out:
# E:\College\Programs\Anaconda Original\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips["total_bill"],kde=False, bins=30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips["total_bill"],kde=False, bins=30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
plt.hist(tips['total_bill'], edgecolor='white')
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='scatter')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
